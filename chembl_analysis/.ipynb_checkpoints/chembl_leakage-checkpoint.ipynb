# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv")

# %%
result_list = []
for idx,(k,v) in enumerate(df.groupby("set_id")):
    v_unique = v.drop_duplicates(subset=["target_id"])
    if len(v_unique) != 2:
        continue
    result = [k] + v_unique.target_id.values.tolist() + v_unique.assay_ids.values.tolist() + v_unique.target_name.values.tolist()
    result += [v_unique.r2.values[0],v_unique.seq_similarity.values[0],v_unique.doc_id.values[0],v_unique.doi.values[0]]
    result_list.append(result)

# %%
cols = ["set_id","target_id_1","target_id_2","assay_id_1","assay_id_2","target_name_1","target_name_2","R2","seq_sim","doc_id","doi"]
result_df = pd.DataFrame(result_list,columns=cols).round(2)

# %%
result_df[["set_id","target_name_1","target_name_2","R2","seq_sim"]].sample(20)
# Out:
#       set_id                                    target_name_1  \
# 1399    1400                              Nociceptin receptor
# 5037    5038            3',5'-cyclic-AMP phosphodiesterase 4B
# 3141    3142               Mitogen-activated protein kinase 8
# 6009    6010             Muscarinic acetylcholine receptor M1
# 297      298                        Protein kinase C eta type
# 1675    1676                             Acetylcholinesterase
# 3863    3864                    Steroid hormone receptor ERR1
# 4254    4255           Potassium channel subfamily K member 3
# 2          3                          D(1A) dopamine receptor
# 1069    1070          Melanocyte-stimulating hormone receptor
# 442      443             Muscarinic acetylcholine receptor M3
# 3775    3776         RAC-beta serine/threonine-protein kinase
# 5106    5107                 Glycogen synthase kinase-3 alpha
# 4205    4206      Sodium channel protein type 9 subunit alpha
# 682      683  Cyclic AMP-dependent transcription factor ATF-1
# 986      987                                Serine protease 1
# 3092    3093            Serine/threonine-protein kinase PAK 1
# 1121    1122                       Melatonin receptor type 1A
# 844      845                                Serine protease 1
# 6105    6106                             Carbonic anhydrase 9
#
#                                           target_name_2    R2  seq_sim
# 1399                         Kappa-type opioid receptor  0.65     0.52
# 5037              3',5'-cyclic-AMP phosphodiesterase 4D  0.87     0.69
# 3141  Interferon-induced, double-stranded RNA-activa...  0.89     0.16
# 6009               Muscarinic acetylcholine receptor M3  0.93     0.56
# 297                         Protein kinase C gamma type  0.64     0.36
# 1675                                     Cholinesterase  0.61     0.51
# 3863                      Steroid hormone receptor ERR2  0.94     0.59
# 4254             Potassium channel subfamily K member 9  0.64     0.61
# 2                                D(3) dopamine receptor  0.62     0.23
# 1069                            Melanocortin receptor 5  0.77     0.46
# 442                Muscarinic acetylcholine receptor M2  0.86     0.46
# 3775          RAC-gamma serine/threonine-protein kinase  0.72     0.77
# 5106                    Glycogen synthase kinase-3 beta  0.84     0.75
# 4205        Sodium channel protein type 5 subunit alpha  0.64     0.62
# 682              Nuclear factor NF-kappa-B p105 subunit  0.95     0.04
# 986                                     Tryptase beta-1  0.76     0.35
# 3092               Serine/threonine-protein kinase TBK1  0.63     0.16
# 1121                         Melatonin receptor type 1B  0.60     0.59
# 844                Urokinase-type plasminogen activator  0.82     0.30
# 6105                              Carbonic anhydrase 12  0.68     0.32

# %%
cutoff_res = []
for cutoff in np.arange(0.1,1,step=0.1):
    cutoff_res.append([cutoff,len(result_df.query("seq_sim <= @cutoff"))])
cutoff_df = pd.DataFrame(cutoff_res,columns=["seq_sim_cutoff","num_papers"])
ax = sns.scatterplot(x="seq_sim_cutoff",y="num_papers",data=cutoff_df)
ax.set_xlabel("Sequence Similairty Cutoff")
ax.set_ylabel("Number of Papers with $R^2$ >= 0.6")
# Out:
# Text(0, 0.5, 'Number of Papers with $R^2$ >= 0.6')

# %%
result_df.sort_values("R2",ascending=False).head(25)
# Out:
#       set_id    target_id_1    target_id_2     assay_id_1     assay_id_2  \
# 2423    2424      CHEMBL254      CHEMBL288  CHEMBL1805697  CHEMBL1805699
# 4497    4498  CHEMBL2424504  CHEMBL3774295  CHEMBL3788932  CHEMBL3788933
# 1751    1752     CHEMBL3807     CHEMBL3521  CHEMBL1053999  CHEMBL1054000
# 5855    5856      CHEMBL205      CHEMBL220  CHEMBL5265198  CHEMBL5265203
# 2022    2023     CHEMBL3729     CHEMBL2186  CHEMBL1074268  CHEMBL1074275
# 2033    2034     CHEMBL3242     CHEMBL2186  CHEMBL1074274  CHEMBL1074275
# 5854    5855      CHEMBL261      CHEMBL220  CHEMBL5265197  CHEMBL5265203
# 4366    4367      CHEMBL325     CHEMBL1937  CHEMBL3596003  CHEMBL3596004
# 3929    3930      CHEMBL253     CHEMBL2470  CHEMBL2383561  CHEMBL2383566
# 4953    4954     CHEMBL4588      CHEMBL321  CHEMBL4193096  CHEMBL4193097
# 5828    5829      CHEMBL230      CHEMBL215  CHEMBL5243104  CHEMBL5243105
# 2422    2423      CHEMBL254      CHEMBL275  CHEMBL1805697  CHEMBL1805698
# 2424    2425      CHEMBL275      CHEMBL288  CHEMBL1805698  CHEMBL1805699
# 3879    3880      CHEMBL321      CHEMBL333  CHEMBL2338836  CHEMBL2338837
# 807      808     CHEMBL1926     CHEMBL2363   CHEMBL664179   CHEMBL665438
# 5246    5247     CHEMBL5800  CHEMBL1697661  CHEMBL4412006  CHEMBL4412007
# 1883    1884     CHEMBL3199      CHEMBL220  CHEMBL1049242  CHEMBL1049243
# 763      764     CHEMBL4588      CHEMBL321   CHEMBL713834   CHEMBL710807
# 2162    2163     CHEMBL3025     CHEMBL2326  CHEMBL1217100  CHEMBL1217101
# 1387    1388      CHEMBL325     CHEMBL5103   CHEMBL889421   CHEMBL889424
# 543      544      CHEMBL216     CHEMBL5498   CHEMBL747393   CHEMBL743825
# 3618    3619      CHEMBL203     CHEMBL1824  CHEMBL1958796  CHEMBL1958797
# 447      448      CHEMBL276      CHEMBL320   CHEMBL746583   CHEMBL742788
# 4593    4594     CHEMBL3594     CHEMBL3242  CHEMBL3874760  CHEMBL3874761
# 2258    2259      CHEMBL325     CHEMBL2563  CHEMBL1634190  CHEMBL1634305
#
#                                          target_name_1  \
# 2423             3',5'-cyclic-AMP phosphodiesterase 4A
# 4497                    Lysine-specific demethylase 5A
# 1751  Tyrosine-protein phosphatase non-receptor type 2
# 5855                              Carbonic anhydrase 2
# 2022                              Carbonic anhydrase 4
# 2033                             Carbonic anhydrase 12
# 5854                              Carbonic anhydrase 1
# 4366                             Histone deacetylase 1
# 3929                            Cannabinoid receptor 2
# 4953                            Neutrophil collagenase
# 5828                      Prostaglandin G/H synthase 2
# 2422             3',5'-cyclic-AMP phosphodiesterase 4A
# 2424             3',5'-cyclic-AMP phosphodiesterase 4B
# 3879                        Matrix metalloproteinase-9
# 807                            Dihydrofolate reductase
# 5246                                       Falcipain 2
# 1883                              Acetylcholinesterase
# 763                             Neutrophil collagenase
# 2162                              Carbonic anhydrase 6
# 1387                             Histone deacetylase 1
# 543               Muscarinic acetylcholine receptor M1
# 3618                  Epidermal growth factor receptor
# 447               Muscarinic acetylcholine receptor M1
# 4593                              Carbonic anhydrase 9
# 2258                             Histone deacetylase 1
#
#                                      target_name_2    R2  seq_sim  \
# 2423         3',5'-cyclic-AMP phosphodiesterase 4D  1.00     0.61
# 4497                Lysine-specific demethylase 5B  1.00     0.53
# 1751  Receptor-type tyrosine-protein phosphatase F  1.00     0.00
# 5855                          Acetylcholinesterase  1.00     0.12
# 2022                         Carbonic anhydrase 13  1.00     0.29
# 2033                         Carbonic anhydrase 13  1.00     0.33
# 5854                          Acetylcholinesterase  1.00     0.12
# 4366                         Histone deacetylase 2  1.00     0.85
# 3929                        Cannabinoid receptor 2  1.00     0.81
# 4953                    Matrix metalloproteinase-9  1.00     0.30
# 5828     Polyunsaturated fatty acid 5-lipoxygenase  1.00     0.16
# 2422         3',5'-cyclic-AMP phosphodiesterase 4B  1.00     0.67
# 2424         3',5'-cyclic-AMP phosphodiesterase 4D  1.00     0.69
# 3879                    72 kDa type IV collagenase  1.00     0.47
# 807                        Dihydrofolate reductase  1.00     0.35
# 5246                 Cysteine protease falcipain-3  1.00     0.55
# 1883                          Acetylcholinesterase  0.99     0.89
# 763                     Matrix metalloproteinase-9  0.99     0.30
# 2162                          Carbonic anhydrase 7  0.99     0.32
# 1387                  Polyamine deacetylase HDAC10  0.99     0.18
# 543           Muscarinic acetylcholine receptor M3  0.99     0.54
# 3618       Receptor tyrosine-protein kinase erbB-2  0.99     0.50
# 447           Muscarinic acetylcholine receptor M3  0.99     0.56
# 4593                         Carbonic anhydrase 12  0.99     0.32
# 2258                         Histone deacetylase 5  0.99     0.09
#
#              doc_id                           doi
# 2423  CHEMBL1799977    10.1016/j.bmcl.2010.09.087
# 4497  CHEMBL3784917  10.1021/acs.jmedchem.5b01758
# 1751  CHEMBL1153002  10.1016/j.ejmech.2009.03.009
# 5855  CHEMBL5260848  10.1016/j.ejmech.2020.112666
# 2022  CHEMBL1157641     10.1016/j.bmc.2010.01.076
# 2033  CHEMBL1157641     10.1016/j.bmc.2010.01.076
# 5854  CHEMBL5260848  10.1016/j.ejmech.2020.112666
# 4366  CHEMBL3593208     10.1016/j.bmc.2015.03.063
# 3929  CHEMBL2380310             10.1021/jm400182t
# 4953  CHEMBL4190296  10.1016/j.ejmech.2017.07.020
# 5828  CHEMBL5241111            10.1039/d1md00280e
# 2422  CHEMBL1799977    10.1016/j.bmcl.2010.09.087
# 2424  CHEMBL1799977    10.1016/j.bmcl.2010.09.087
# 3879  CHEMBL2331288    10.1016/j.bmcl.2013.01.027
# 807   CHEMBL1134503             10.1021/jm0100382
# 5246  CHEMBL4411274  10.1016/j.ejmech.2018.12.001
# 1883  CHEMBL1154069  10.1016/j.ejmech.2009.04.042
# 763   CHEMBL1133677             10.1021/jm000027t
# 2162  CHEMBL1212818             10.1021/jm1003667
# 1387  CHEMBL1145385             10.1021/jm070178x
# 543   CHEMBL1128229           10.1021/jm00003a011
# 3618  CHEMBL1955848     10.1016/j.bmc.2012.01.051
# 447   CHEMBL1125891           10.1021/jm00115a003
# 4593  CHEMBL3872261     10.1016/j.bmc.2016.11.039
# 2258  CHEMBL1629537             10.1021/jm101092u

# %% [raw]
# result_df.query("doi == '10.1016/s0960-894x(98)00351-5'")

# %%
doc_df = df.query("doc_id == 'CHEMBL1131391'").copy()
cols = ['molregno','target_name','pchembl']
pivot_df = pd.pivot_table(doc_df[cols],values=['pchembl'],columns=['target_name'],index=["molregno"])
pivot_df.columns = pivot_df.columns.droplevel(0)
pivot_df.columns.name = None
pivot_df.columns = ["M1","M2","M3","M4","M5"]

# %%
result_df.query("doc_id == 'CHEMBL1131391'").drop_duplicates("set_id")
# Out:
#     set_id target_id_1 target_id_2    assay_id_1    assay_id_2  \
# 63      64   CHEMBL211  CHEMBL1821  CHEMBL747774  CHEMBL749766
# 64      65   CHEMBL216   CHEMBL245  CHEMBL748282  CHEMBL745650
# 65      66   CHEMBL216  CHEMBL2035  CHEMBL748282  CHEMBL748448
# 66      67   CHEMBL245  CHEMBL1821  CHEMBL745650  CHEMBL749766
# 67      68   CHEMBL245  CHEMBL2035  CHEMBL745650  CHEMBL748448
#
#                            target_name_1  \
# 63  Muscarinic acetylcholine receptor M2
# 64  Muscarinic acetylcholine receptor M1
# 65  Muscarinic acetylcholine receptor M1
# 66  Muscarinic acetylcholine receptor M3
# 67  Muscarinic acetylcholine receptor M3
#
#                            target_name_2    R2  seq_sim         doc_id  \
# 63  Muscarinic acetylcholine receptor M4  0.64     0.59  CHEMBL1131391
# 64  Muscarinic acetylcholine receptor M3  0.82     0.56  CHEMBL1131391
# 65  Muscarinic acetylcholine receptor M5  0.93     0.55  CHEMBL1131391
# 66  Muscarinic acetylcholine receptor M4  0.62     0.47  CHEMBL1131391
# 67  Muscarinic acetylcholine receptor M5  0.79     0.53  CHEMBL1131391
#
#                               doi
# 63  10.1016/s0960-894x(98)00351-5
# 64  10.1016/s0960-894x(98)00351-5
# 65  10.1016/s0960-894x(98)00351-5
# 66  10.1016/s0960-894x(98)00351-5
# 67  10.1016/s0960-894x(98)00351-5

# %%
sns.set_context('talk')
def corrfunc(x, y, ax=None, **kws):
    # 1. Clean data: Remove rows where either x or y is NaN
    df_temp = pd.DataFrame({'x': x, 'y': y}).dropna()
    
    # 2. Safety check for insufficient data or zero variation
    if len(df_temp) < 2 or df_temp['x'].std() == 0 or df_temp['y'].std() == 0:
        r_text = "N/A"
        text_color = "black"
        is_bold = "normal"
    else:
        # 3. Calculate Pearson r
        r, _ = pearsonr(df_temp['x'], df_temp['y'])
        r_text = f'r = {r:.2f}'
        
        # 4. Logic: Blue and Bold if >= 0.77, else Red and Normal
        if r >= 0.77:
            text_color = "blue"
            is_bold = "bold"
        else:
            text_color = "red"
            is_bold = "normal"

    # 5. Annotate the plot
    ax = ax or plt.gca()
    ax.annotate(r_text, 
                xy=(.1, .9), 
                xycoords=ax.transAxes, 
                color=text_color, 
                fontweight=is_bold)
        
# 2. Initialize the Grid
g = sns.PairGrid(pivot_df)

# 3. Map different functions to sections
g.map_diag(sns.histplot)      # Diagonals (e.g., histograms)
g.map_lower(sns.scatterplot)  # Lower triangle (e.g., scatter plots)
g.map_upper(corrfunc)         # Upper triangle (your Pearson r function)
